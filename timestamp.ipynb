# %%
import pandas as pd
y=pd.Period('2021')
y
# Out:
# Period('2021', 'A-DEC')

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_add_delta',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_typ',
#  'asfreq',
#  'day',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
y.start_time
# Out:
# Timestamp('2021-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2021-12-31 23:59:59.999999999')

# %%
m=pd.Period('2021-1',freq='M')
m
# Out:
# Period('2021-01', 'M')

# %%
m+1            #gives following month based on frequency
# Out:
# Period('2021-02', 'M')

# %%
d=pd.Period('2021-12-31 23:00:00',freq='D')
d
# Out:
# Period('2021-12-31', 'D')

# %%
d+1
# Out:
# Period('2022-01-01', 'D')

# %%
d=pd.Period('2021-12-31 23:00:00',freq='H')
d
# Out:
# Period('2021-12-31 23:00', 'H')

# %%
d+pd.offsets.Hour(5)
# Out:
# Period('2022-01-01 04:00', 'H')

# %%
q=pd.Period('2021Q1','Q-DEC')
q
# Out:
# Period('2021Q1', 'Q-DEC')

# %%
q+1           #give start and end time, gives results based on the given periods
# Out:
# Period('2021Q2', 'Q-DEC')

# %%
q=pd.Period('2021Q1',freq='Q-JAN')          #if fiscal is different
q
# Out:
# Period('2021Q1', 'Q-JAN')

# %%
q.start_time
# Out:
# Timestamp('2020-02-01 00:00:00')

# %%
q.end_time
# Out:
# Timestamp('2020-04-30 23:59:59.999999999')

# %%
q.asfreq('M',how="end")       # to convert frequency to different frequency
# Out:
# Period('2020-04', 'M')

# %%
q.asfreq('M',how="start")
# Out:
# Period('2020-02', 'M')

# %%
q2=pd.Period('2021Q2',freq='Q-JAN')
q2
# Out:
# Period('2021Q2', 'Q-JAN')

# %%
q2-q        #works only with same frequencies(operations)
# Out:
# <QuarterEnd: startingMonth=1>

# %%
idx=pd.period_range('2011','2017',freq='Q')
idx
# Out:
# PeriodIndex(['2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2',
#              '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4',
#              '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2',
#              '2015Q3', '2015Q4', '2016Q1', '2016Q2', '2016Q3', '2016Q4',
#              '2017Q1'],
#             dtype='period[Q-DEC]', freq='Q-DEC')

# %%
idx=pd.period_range('2011','2017',freq='Q-JAN')      #for varying fiscal years Q-JAN
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3',
#              '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
#              '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#              '2017Q4'],
#             dtype='period[Q-JAN]', freq='Q-JAN')

# %%
idx[0].start_time     #start of fiscal year for above quarter 2011Q4
# Out:
# Timestamp('2010-11-01 00:00:00')

# %%
idx[0].start_time     #end of fiscal year above quarter  2011Q4
# Out:
# Timestamp('2010-11-01 00:00:00')

# %%
idx=pd.period_range('2011',periods=10,freq='Q-JAN')      #for varying fiscal years Q-JAN
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]', freq='Q-JAN')

# %%
import numpy as np                                 #numpy function to create series
ps=pd.Series(np.random.randn(len(idx)),idx)
ps
# Out:
# 2011Q4   -0.814936
# 2012Q1   -0.708632
# 2012Q2    0.839669
# 2012Q3   -2.378949
# 2012Q4   -0.347669
# 2013Q1   -2.957832
# 2013Q2   -0.103840
# 2013Q3    1.823248
# 2013Q4   -0.964301
# 2014Q1    0.865721
# Freq: Q-JAN, dtype: float64

# %%
ps.index
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]', freq='Q-JAN')

# %%
ps['2011']
# Out:
# 2011Q4   -0.814936
# 2012Q1   -0.708632
# 2012Q2    0.839669
# 2012Q3   -2.378949
# 2012Q4   -0.347669
# Freq: Q-JAN, dtype: float64

# %%
ps['2011':'2013']
# Out:
# 2011Q4   -0.814936
# 2012Q1   -0.708632
# 2012Q2    0.839669
# 2012Q3   -2.378949
# 2012Q4   -0.347669
# 2013Q1   -2.957832
# 2013Q2   -0.103840
# 2013Q3    1.823248
# 2013Q4   -0.964301
# 2014Q1    0.865721
# Freq: Q-JAN, dtype: float64

# %%
pst=ps.to_timestamp()     #gives datetime index from period index
pst
# Out:
# 2010-11-01   -0.814936
# 2011-02-01   -0.708632
# 2011-05-01    0.839669
# 2011-08-01   -2.378949
# 2011-11-01   -0.347669
# 2012-02-01   -2.957832
# 2012-05-01   -0.103840
# 2012-08-01    1.823248
# 2012-11-01   -0.964301
# 2013-02-01    0.865721
# Freq: QS-NOV, dtype: float64

# %%
pst.index
# Out:
# DatetimeIndex(['2010-11-01', '2011-02-01', '2011-05-01', '2011-08-01',
#                '2011-11-01', '2012-02-01', '2012-05-01', '2012-08-01',
#                '2012-11-01', '2013-02-01'],
#               dtype='datetime64[ns]', freq='QS-NOV')

# %%
pst.to_period()           #to getback to period index
# Out:
# 2010Q4   -0.814936
# 2011Q1   -0.708632
# 2011Q2    0.839669
# 2011Q3   -2.378949
# 2011Q4   -0.347669
# 2012Q1   -2.957832
# 2012Q2   -0.103840
# 2012Q3    1.823248
# 2012Q4   -0.964301
# 2013Q1    0.865721
# Freq: Q-DEC, dtype: float64

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\dell\\Downloads\\Desktop\\AAPL2.xlsx")
df
# Out:
#            Open        High         Low       Close   Adj Close     Volume
# 0    159.570007  160.449997  156.360001  156.809998  155.905167   76959800
# 1    159.369995  161.190002  158.789993  160.240005  159.315369   88748200
# 2    159.990005  165.520004  159.919998  165.300003  164.346176  174048100
# 3    167.479996  170.300003  164.529999  164.770004  163.819244  152052500
# 4    158.740005  164.199997  157.800003  163.759995  162.815048  136739200
# 5    164.020004  164.960007  159.720001  161.839996  160.906143  118023100
# 6    164.289993  167.880005  164.279999  165.320007  164.366058  107497000
# 7    169.080002  171.580002  168.339996  171.179993  170.192215  120405400
# 8    172.130005  175.960007  170.699997  175.080002  174.069748  116998900
# 9    174.910004  176.750000  173.919998  174.559998  173.552734  108923700
# 10   175.210007  179.630005  174.690002  179.449997  178.414520  115402700
# ...

# %%
df.set_index('Open',inplace=True)
df
# Out:
#                   High         Low       Close   Adj Close     Volume
# Open
# 159.570007  160.449997  156.360001  156.809998  155.905167   76959800
# 159.369995  161.190002  158.789993  160.240005  159.315369   88748200
# 159.990005  165.520004  159.919998  165.300003  164.346176  174048100
# 167.479996  170.300003  164.529999  164.770004  163.819244  152052500
# 158.740005  164.199997  157.800003  163.759995  162.815048  136739200
# 164.020004  164.960007  159.720001  161.839996  160.906143  118023100
# 164.289993  167.880005  164.279999  165.320007  164.366058  107497000
# 169.080002  171.580002  168.339996  171.179993  170.192215  120405400
# 172.130005  175.960007  170.699997  175.080002  174.069748  116998900
# 174.910004  176.750000  173.919998  174.559998  173.552734  108923700
# 175.210007  179.630005  174.690002  179.449997  178.414520  115402700
# 181.119995  182.130005  175.529999  175.740005  174.725937  153237000
# ...

# %%
df=df.T #changes rows as colums and columns as rows
df
# Out:
#                   High         Low       Close   Adj Close       Volume
# Open
# 159.570007  160.449997  156.360001  156.809998  155.905167   76959800.0
# 159.369995  161.190002  158.789993  160.240005  159.315369   88748200.0
# 159.990005  165.520004  159.919998  165.300003  164.346176  174048100.0
# 167.479996  170.300003  164.529999  164.770004  163.819244  152052500.0
# 158.740005  164.199997  157.800003  163.759995  162.815048  136739200.0
# 164.020004  164.960007  159.720001  161.839996  160.906143  118023100.0
# 164.289993  167.880005  164.279999  165.320007  164.366058  107497000.0
# 169.080002  171.580002  168.339996  171.179993  170.192215  120405400.0
# 172.130005  175.960007  170.699997  175.080002  174.069748  116998900.0
# 174.910004  176.750000  173.919998  174.559998  173.552734  108923700.0
# 175.210007  179.630005  174.690002  179.449997  178.414520  115402700.0
# 181.119995  182.130005  175.529999  175.740005  174.725937  153237000.0
# ...

# %%
df.index=pd.PeriodIndex(df.index,freq='Q-JAN')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-b74c06c5b751> in <module>
# ----> 1 df.index=pd.PeriodIndex(df.index,freq='Q-JAN')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\period.py in __new__(cls, data, ordinal, freq, start, end, periods, tz, dtype, copy, name, **fields)
#     238             else:
#     239                 # don't pass copy here, since we copy later.
# --> 240                 data = period_array(data=data, freq=freq)
#     241
#     242         if copy:
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\period.py in period_array(data, freq, copy)
#     781
#     782     if is_float_dtype(data) and len(data) > 0:
# --> 783         raise TypeError("PeriodIndex does not allow "
#     784                         "floating point in construction")
#     785
#
# TypeError: PeriodIndex does not allow floating point in construction

# %%
df['start_date']=df.index.map(lamda x: x.start_time)     #takes functionas argument
# Out:
#   File "<ipython-input-63-9d2775b328df>", line 1
#     df['start_date']=df.index.map(lamda x: x.start_time)     #takes functionas argument
#                                         ^
# SyntaxError: invalid syntax

# %%
df['end_date']=df.index.map(lamda x: x.end_time)
